# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trash_hauler_report = pd.read_csv('../data/trash_hauler_report.csv')

# %%
trash_hauler_report.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# ...

# %%
trash_hauler_report.tail()
# Out:
#        Request Number Date Opened                              Request   \
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 20221                             2731 Murfreesboro Pike   37013.0
# ...

# %%
trash_hauler_report.columns
# Out:
# Index(['Request Number', 'Date Opened', 'Request ', 'Description',
#        'Incident Address', 'Zip Code', 'Trash Hauler', 'Trash Route',
#        'Council District', 'State Plan X', 'State Plan Y'],
#       dtype='object')

# %%
trash_hauler_report = trash_hauler_report.rename(columns = {'Request ': 'Request'})
trash_hauler_report.columns
# Out:
# Index(['Request Number', 'Date Opened', 'Request', 'Description',
#        'Incident Address', 'Zip Code', 'Trash Hauler', 'Trash Route',
#        'Council District', 'State Plan X', 'State Plan Y'],
#       dtype='object')

# %%
trash_hauler_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
#counting nulls
trash_hauler_report.isnull().sum()
# Out:
# Request Number        0
# Date Opened           0
# Request               0
# Description          31
# Incident Address      9
# Zip Code             75
# Trash Hauler        901
# Trash Route         947
# Council District     49
# State Plan X         28
# State Plan Y         28
# dtype: int64

# %%
trash_hauler_report.shape
# Out:
# (20226, 11)

# %%
#capitalizing first letter in ever word for addresses
trash_hauler_report['Incident Address'].str.title()
# Out:
# 0                                           3817 Crouch Dr
# 1                                    4028 Clarksville Pike
# 2                                      6528 Thunderbird Dr
# 3                                     2603 Old Matthews Rd
# 4                                            604 Croley Dr
#                                ...
# 20221                               2731 Murfreesboro Pike
# 20222    1621 Long Ave, Nashville, Tn 37206, United States
# 20223    2943 Windemere Cir, Nashville, Tn 37214, Unite...
# 20224    3325 Murfreesboro Pike, Nashville, Tn 37013, U...
# 20225    604 Somerset Ct, Nashville, Tn 37217, United S...
# Name: Incident Address, Length: 20226, dtype: object

# %%
#capitalizing first letter in every word for addresses put in effect
trash_hauler_report['Incident Address'] = trash_hauler_report['Incident Address'].str.title()

# %%
trash_hauler_report.head()
# Out:
#    Request Number Date Opened                               Request  \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 Old Matthews Rd
# 4                  Missed the even side of the road.          604 Croley Dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# ...

# %%
trash_hauler_report.tail()
# Out:
#        Request Number Date Opened                               Request  \
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 20221                             2731 Murfreesboro Pike   37013.0
# ...

# %%
trash_hauler_report['Request'].value_counts()
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    15028
# Trash - Backdoor                         2629
# Trash Collection Complaint               2312
# Damage to Property                        257
# Name: count, dtype: int64

# %%
trash_hauler_report['Zip Code'] = trash_hauler_report['Zip Code'].astype(str)

# %%
trash_hauler_report['Zip Code'] = trash_hauler_report['Zip Code'].str[:5]

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report['Description'] = trash_hauler_report['Description'].str.lower()

# %%
trash_hauler_report['Trash Hauler'].value_counts()
# Out:
# Trash Hauler
# RED RIVER    14395
# METRO         3512
# WASTE IND     1350
# Metro           68
# Name: count, dtype: int64

# %%
#changing trash hauler company names to str.title so that the Metro was the same as METRO
trash_hauler_report['Trash Hauler'] = trash_hauler_report['Trash Hauler'].str.title()

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report.shape
# Out:
# (20226, 11)

# %%
trash_hauler_report['Zip Code'].value_counts()
# Out:
# Zip Code
# 37013    2278
# 37211    2248
# 37205    1491
# 37209    1411
# 37215    1404
# 37207    1300
# 37115    1266
# 37206    1217
# 37208    1039
# 37214    1004
# 37218     983
# 37216     841
# 37217     832
# 37204     635
# 37212     601
# 37210     550
# 37203     394
# 37220     289
# 37027     168
# nan        75
# 37189      60
# 37221      48
# 37219      42
# 37201      35
# 37076       5
# 37138       5
# 37086       3
# 37213       1
# 37228       1
# Name: count, dtype: int64

# %%
#finding date counts
trash_hauler_report['Date Opened'].value_counts()
# Out:
# Date Opened
# 08/02/19    252
# 10/18/19    189
# 10/17/19    181
# 08/16/19    176
# 10/16/19    166
#            ...
# 11/24/17      1
# 03/17/19      1
# 09/29/19      1
# 05/12/19      1
# 03/16/19      1
# Name: count, Length: 686, dtype: int64

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report['Request'].value_counts().plot(kind = 'bar')
plt.title('Number of Request by Type', fontweight = 'bold');

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report['miss'] = (trash_hauler_report['Description'].str.contains('miss', case = False) |
                        trash_hauler_report['Request'].str.contains('miss', case = False))       
##trash_missed = trash_hauler_report

# %%
trash_missed = trash_hauler_report.loc[trash_hauler_report.miss == True]

# %%
trash_missed
# Out:
#        Request Number Date Opened                               Request  \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 7               25327    11/01/17            Trash Collection Complaint
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_missed.shape
# Out:
# (17710, 12)

# %%
trash_missed['Request'].value_counts()
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    14999
# Trash - Backdoor                         2017
# Trash Collection Complaint                691
# Damage to Property                          3
# Name: count, dtype: int64

# %%
trash_missed
# Out:
#        Request Number Date Opened                               Request  \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 7               25327    11/01/17            Trash Collection Complaint
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_miss = trash_hauler_report.loc[trash_hauler_report['Description'].str.contains('miss', case= False, na=False)]

# %%
trash_missed
# Out:
#        Request Number Date Opened                               Request  \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 7               25327    11/01/17            Trash Collection Complaint
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
missed_by_route = trash_missed.groupby('Trash Route')['miss'].count()

# %%
missed_by_route.describe()
# Out:
# count    172.000000
# mean      98.523256
# std       70.049227
# min        1.000000
# 25%       43.000000
# 50%       83.500000
# 75%      141.500000
# max      328.000000
# Name: miss, dtype: float64

# %%
missed_by_route
# Out:
# Trash Route
# 1201     174
# 1202      93
# 1202S      4
# 1203      74
# 1204      68
#         ...
# 9504      44
# 9505      57
# 9506      68
# 9507      75
# 9508     121
# Name: miss, Length: 172, dtype: int64

# %%
trash_missed['Trash Hauler'].value_counts().plot(kind = 'bar')
plt.title('Number of Missed Pickups by Trash Hauler', fontweight = 'bold');
