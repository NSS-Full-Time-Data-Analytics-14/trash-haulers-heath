# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trash_hauler_report = pd.read_csv('../data/trash_hauler_report.csv')

# %%
trash_hauler_report.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# ...

# %%
trash_hauler_report.tail()
# Out:
#        Request Number Date Opened                              Request   \
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 20221                             2731 Murfreesboro Pike   37013.0
# ...

# %%
trash_hauler_report.columns
# Out:
# Index(['Request Number', 'Date Opened', 'Request ', 'Description',
#        'Incident Address', 'Zip Code', 'Trash Hauler', 'Trash Route',
#        'Council District', 'State Plan X', 'State Plan Y'],
#       dtype='object')

# %%
trash_hauler_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
trash_hauler_report.isna().sum()
# Out:
# Request Number        0
# Date Opened           0
# Request               0
# Description          31
# Incident Address      9
# Zip Code             75
# Trash Hauler        901
# Trash Route         947
# Council District     49
# State Plan X         28
# State Plan Y         28
# dtype: int64

# %%
trash_hauler_report.shape
# Out:
# (20226, 11)

# %%
trash_hauler_report['Incident Address'].str.title()
# Out:
# 0                                           3817 Crouch Dr
# 1                                    4028 Clarksville Pike
# 2                                      6528 Thunderbird Dr
# 3                                     2603 Old Matthews Rd
# 4                                            604 Croley Dr
#                                ...
# 20221                               2731 Murfreesboro Pike
# 20222    1621 Long Ave, Nashville, Tn 37206, United States
# 20223    2943 Windemere Cir, Nashville, Tn 37214, Unite...
# 20224    3325 Murfreesboro Pike, Nashville, Tn 37013, U...
# 20225    604 Somerset Ct, Nashville, Tn 37217, United S...
# Name: Incident Address, Length: 20226, dtype: object

# %%
trash_hauler_report['Incident Address'] = trash_hauler_report['Incident Address'].str.title()

# %%
trash_hauler_report.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 Old Matthews Rd
# 4                  Missed the even side of the road.          604 Croley Dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# ...

# %%
trash_hauler_report.tail()
# Out:
#        Request Number Date Opened                              Request   \
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 20221                             2731 Murfreesboro Pike   37013.0
# ...

# %%
trash_hauler_report['Request '].value_counts()
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    15028
# Trash - Backdoor                         2629
# Trash Collection Complaint               2312
# Damage to Property                        257
# Name: count, dtype: int64

# %%
trash_missed = trash_hauler_report.loc[trash_hauler_report['Request '] == 'Trash - Curbside/Alley Missed Pickup']
trash_missed.head()
# Out:
#    Request Number Date Opened                              Request   \
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 8           25330    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                          Description               Incident Address  Zip Code  \
# 1           Curb/Trash miss Tuesday.          4028 Clarksville Pike   37218.0
# 2           Curb/trash miss Tuesday.            6528 Thunderbird Dr   37209.0
# 3                             missed           2603 Old Matthews Rd   37207.0
# 4  Missed the even side of the road.                  604 Croley Dr   37209.0
# 8                            Missed.  4484 Lavergne Couchville Pike   37013.0
#
#   Trash Hauler Trash Route  Council District  State Plan X   State Plan Y
# ...

# %%
trash_missed['Request '].value_counts()
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    15028
# Name: count, dtype: int64

# %%
trash_hauler_report['Zip Code'].value_counts()
# Out:
# Zip Code
# 37013.0    2278
# 37211.0    2248
# 37205.0    1491
# 37209.0    1411
# 37215.0    1404
# 37207.0    1300
# 37115.0    1266
# 37206.0    1217
# 37208.0    1039
# 37214.0    1004
# 37218.0     983
# 37216.0     841
# 37217.0     832
# 37204.0     635
# 37212.0     601
# 37210.0     550
# 37203.0     394
# 37220.0     289
# 37027.0     168
# 37189.0      60
# 37221.0      48
# 37219.0      42
# 37201.0      35
# 37076.0       5
# 37138.0       5
# 37086.0       3
# 37213.0       1
# 37228.0       1
# Name: count, dtype: int64

# %%
trash_hauler_report['Trash Hauler'] = trash_hauler_report['Trash Hauler'].str.title()

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report['Date Opened'].value_counts()
# Out:
# Date Opened
# 08/02/19    252
# 10/18/19    189
# 10/17/19    181
# 08/16/19    176
# 10/16/19    166
#            ...
# 11/24/17      1
# 03/17/19      1
# 09/29/19      1
# 05/12/19      1
# 03/16/19      1
# Name: count, Length: 686, dtype: int64

# %%
trash_hauler_report.loc[trash_hauler_report['Description'] == 'Missed'].head()
# Out:
#      Request Number Date Opened                              Request   \
# 100           25987    11/03/17  Trash - Curbside/Alley Missed Pickup
# 110           26039    11/03/17  Trash - Curbside/Alley Missed Pickup
# 262           28207    11/15/17  Trash - Curbside/Alley Missed Pickup
# 270           28310    11/15/17  Trash - Curbside/Alley Missed Pickup
# 296           28577    11/16/17  Trash - Curbside/Alley Missed Pickup
#
#     Description     Incident Address  Zip Code Trash Hauler Trash Route  \
# 100      Missed      1609 Lillian St   37206.0        Metro        9506
# 110      Missed       816 Dresden Ct   37013.0    Red River        3502
# 262      Missed       1837 Meade Ave   37207.0    Red River        3202
# 270      Missed  736 Branch Creek Rd   37209.0    Red River        2301
# 296      Missed    582 Valleywood Dr   37211.0    Red River        3401
#
#      Council District  State Plan X   State Plan Y
# 100               6.0  1.749558e+06  670298.400857
# ...

# %%
trash_hauler_report.loc[trash_hauler_report['Description'] == 'missed'].head()
# Out:
#      Request Number Date Opened                              Request   \
# 3             25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 136           26283    11/06/17  Trash - Curbside/Alley Missed Pickup
# 137           26284    11/06/17  Trash - Curbside/Alley Missed Pickup
# 172           26906    11/08/17                      Trash - Backdoor
# 180           27029    11/08/17  Trash - Curbside/Alley Missed Pickup
#
#     Description        Incident Address  Zip Code Trash Hauler Trash Route  \
# 3        missed    2603 Old Matthews Rd   37207.0    Waste Ind        2206
# 136      missed  3124 Murfreesboro Pike   37013.0    Red River        4502
# 137      missed  3124 Murfreesboro Pike   37013.0    Red River        4502
# 172      missed           4208 Kings Ct   37218.0    Red River        3203
# 180      missed          2505 Booker St   37208.0        Metro        9303
#
#      Council District  State Plan X   State Plan Y
# ...

# %%
trash_hauler_report

# %%
trash_hauler_report.Description.value_counts()
# Out:
# Description
# miss                                                                                                                                                                                                                                                                                        899
# Missed.                                                                                                                                                                                                                                                                                     602
# missed                                                                                                                                                                                                                                                                                      335
# ...

# %%
trash_hauler_report.isna().sum()
# Out:
# Request Number        0
# Date Opened           0
# Request               0
# Description          31
# Incident Address      9
# Zip Code             75
# Trash Hauler        901
# Trash Route         947
# Council District     49
# State Plan X         28
# State Plan Y         28
# dtype: int64

# %%
trash_hauler_report['Description'] = trash_hauler_report['Description'].str.lower()

# %%
trash_hauler_report
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash_hauler_report
